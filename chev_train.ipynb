# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("training_data.csv")

# %%
data
# Out:
#        Date Vehicle Category      GVWR Class Fuel Type  Model Year  \
# 0      2019                P  Not Applicable  Gasoline      2020.0
# 1      2020                P  Not Applicable  Gasoline      2020.0
# 2      2021                P  Not Applicable  Gasoline      2020.0
# 3      2019                P  Not Applicable  Gasoline      2019.0
# 4      2019                P  Not Applicable  Gasoline      2018.0
# ...     ...              ...             ...       ...         ...
# 41048  2019                B  Not Applicable    Diesel      1983.0
# 41049  2019                B  Not Applicable    Diesel      1980.0
# 41050  2019                B  Not Applicable    Diesel      1978.0
# 41051  2019                B  Not Applicable    Diesel      1976.0
# 41052  2019                B  Not Applicable    Diesel      1976.0
#
#       Fuel Technology Electric Mile Range  \
# 0                 ICE      Not Applicable
# 1                 ICE      Not Applicable
# 2                 ICE      Not Applicable
# 3                 ICE      Not Applicable
# 4                 ICE      Not Applicable
# ...               ...                 ...
# 41048             ICE      Not Applicable
# 41049             ICE      Not Applicable
# 41050             ICE      Not Applicable
# 41051             ICE      Not Applicable
# 41052             ICE      Not Applicable
#
#       Number of Vehicles Registered at the Same Address     Region  \
# 0                                                    ≥4  Statewide
# 1                                                     1  Statewide
# 2                                                     1  Statewide
# 3                                                    ≥4  Statewide
# 4                                                    ≥4  Statewide
# ...                                                 ...        ...
# 41048                                                 1  Statewide
# 41049                                                 2  Statewide
# 41050                                                 3  Statewide
# 41051                                                 2  Statewide
# 41052                                                 3  Statewide
#
#        Vehicle Population
# 0                  395883
# 1                  370954
# 2                  349406
# 3                  348475
# 4                  333296
# ...                   ...
# 41048                   1
# 41049                   1
# 41050                   1
# 41051                   1
# 41052                   1
#
# [41053 rows x 10 columns]

# %%
df = pd.DataFrame(data)
df.drop_duplicates()
df
# Out:
#        Date Vehicle Category      GVWR Class Fuel Type  Model Year  \
# 0      2019                P  Not Applicable  Gasoline      2020.0
# 1      2020                P  Not Applicable  Gasoline      2020.0
# 2      2021                P  Not Applicable  Gasoline      2020.0
# 3      2019                P  Not Applicable  Gasoline      2019.0
# 4      2019                P  Not Applicable  Gasoline      2018.0
# ...     ...              ...             ...       ...         ...
# 41048  2019                B  Not Applicable    Diesel      1983.0
# 41049  2019                B  Not Applicable    Diesel      1980.0
# 41050  2019                B  Not Applicable    Diesel      1978.0
# 41051  2019                B  Not Applicable    Diesel      1976.0
# 41052  2019                B  Not Applicable    Diesel      1976.0
#
#       Fuel Technology Electric Mile Range  \
# 0                 ICE      Not Applicable
# 1                 ICE      Not Applicable
# 2                 ICE      Not Applicable
# 3                 ICE      Not Applicable
# 4                 ICE      Not Applicable
# ...               ...                 ...
# 41048             ICE      Not Applicable
# 41049             ICE      Not Applicable
# 41050             ICE      Not Applicable
# 41051             ICE      Not Applicable
# 41052             ICE      Not Applicable
#
#       Number of Vehicles Registered at the Same Address     Region  \
# 0                                                    ≥4  Statewide
# 1                                                     1  Statewide
# 2                                                     1  Statewide
# 3                                                    ≥4  Statewide
# 4                                                    ≥4  Statewide
# ...                                                 ...        ...
# 41048                                                 1  Statewide
# 41049                                                 2  Statewide
# 41050                                                 3  Statewide
# 41051                                                 2  Statewide
# 41052                                                 3  Statewide
#
#        Vehicle Population
# 0                  395883
# 1                  370954
# 2                  349406
# 3                  348475
# 4                  333296
# ...                   ...
# 41048                   1
# 41049                   1
# 41050                   1
# 41051                   1
# 41052                   1
#
# [41053 rows x 10 columns]

# %%
print(df.dtypes)
# Out:
# Date                                                  int64
# Vehicle Category                                     object
# GVWR Class                                           object
# Fuel Type                                            object
# Model Year                                            int64
# Fuel Technology                                      object
# Electric Mile Range                                  object
# Number of Vehicles Registered at the Same Address    object
# Region                                               object
# Vehicle Population                                    int64
# dtype: object

# %%
# Check for missing values in "Model Year"
missing_model_year = df["Model Year"].isna().sum()
print(f"Total missing 'Model Year' values: {missing_model_year}")
# Out:
# Total missing 'Model Year' values: 0

# %%
df = df.dropna(subset=["Model Year"]).sort_values(by="Date", ascending=True).reset_index(drop=True)

# %%
df["Model Year"] = df["Model Year"].astype(int)

# %%
import json

# Generate summary JSON as a string
summary_json = df.describe(include="all").to_json()
summary_dict = json.loads(summary_json)
# Write the JSON dictionary to a file with indentation
with open("summary.json", "w") as f:
    json.dump(summary_dict, f, indent=4)

# %%
df.drop(labels = "Region", axis = 1)
# Out:
#        Date Vehicle Category      GVWR Class    Fuel Type  Model Year  \
# 0      2019                P  Not Applicable     Gasoline        2020
# 1      2019               T6               7       Diesel        1996
# 2      2019               T6               7       Diesel        1993
# 3      2019               T6               6       Diesel        1986
# 4      2019               T4         Unknown       Diesel        1992
# ...     ...              ...             ...          ...         ...
# 40445  2023               BS  Not Applicable       Diesel        1999
# 40446  2023                B  Not Applicable       Diesel        2024
# 40447  2023                B  Not Applicable       Diesel        2019
# 40448  2023                B  Not Applicable       Diesel        2016
# 40449  2023                B  Not Applicable  Natural Gas        2023
#
#       Fuel Technology Electric Mile Range  \
# 0                 ICE      Not Applicable
# 1                 ICE      Not Applicable
# 2                 ICE      Not Applicable
# 3                 ICE      Not Applicable
# 4                 ICE      Not Applicable
# ...               ...                 ...
# 40445             ICE      Not Applicable
# 40446             ICE      Not Applicable
# 40447             ICE      Not Applicable
# 40448             ICE      Not Applicable
# 40449             ICE      Not Applicable
#
#       Number of Vehicles Registered at the Same Address  Vehicle Population
# 0                                                    ≥4              395883
# 1                                                     1                  70
# 2                                                     1                  70
# 3                                                    ≥4                  70
# 4                                                    ≥4                  70
# ...                                                 ...                 ...
# 40445                                                 1                  12
# 40446                                                 1                  12
# 40447                                                 3                  12
# 40448                                                 3                  12
# 40449                                                ≥4                  39
#
# [40450 rows x 9 columns]

# %%
df.to_csv("cleaned_data.csv")
